# %% [markdown]
# This is the project of Tritek that i made up my mind to do with python porgraming language

# %% [markdown]
# Need to check the data set and to see the leavel of clearning that the project will
# need

# %%
import numpy as np
import pandas as pd 
import statsmodels.api as sn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
sns.set()

# %%
cont = pd.read_csv("content.csv")
prof = pd.read_csv("Profile (1).csv")
reat= pd.read_csv("Reactions (1).csv")
loca = pd.read_csv("Location (1).csv")
reat_typ = pd.read_csv("ReactionTypes (1).csv")
sess = pd.read_csv("Session (1).csv")
user = pd.read_csv("User (1).csv")

# %%
user. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   User ID     500 non-null    object
#  2   Name        500 non-null    object
#  3   Email       500 non-null    object
# dtypes: int64(1), object(3)
# memory usage: 15.8+ KB

# %%
sess. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   User ID     500 non-null    object
#  2   Device      500 non-null    object
#  3   Duration    500 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 15.8+ KB

# %%
reat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25553 entries, 0 to 25552
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  25553 non-null  int64
#  1   Content ID  25553 non-null  object
#  2   User ID     22534 non-null  object
#  3   Type        24573 non-null  object
#  4   Datetime    25553 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 998.3+ KB

# %%
reat_typ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  16 non-null     int64
#  1   Type        16 non-null     object
#  2   Sentiment   16 non-null     object
#  3   Score       16 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 640.0+ bytes

# %%
prof.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   User ID     500 non-null    object
#  2   Interests   500 non-null    object
#  3   Age         500 non-null    int64
# dtypes: int64(2), object(2)
# memory usage: 15.8+ KB

# %%
cont.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Content ID  1000 non-null   object
#  2   User ID     1000 non-null   object
#  3   Type        1000 non-null   object
#  4   Category    1000 non-null   object
#  5   URL         801 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
loca.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   User ID     500 non-null    object
#  2   Address     500 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 11.8+ KB

# %%
sess.describe(include="all")
# Out:
#         Unnamed: 0                               User ID    Device    Duration
# count   500.000000                                   500       500  500.000000
# unique         NaN                                   500        13         NaN
# top            NaN  3ae50cc3-39cc-440a-8e31-3215011f2762  Motorola         NaN
# freq           NaN                                     1        77         NaN
# mean    249.500000                                   NaN       NaN   47.706000
# std     144.481833                                   NaN       NaN   29.325681
# min       0.000000                                   NaN       NaN    0.000000
# 25%     124.750000                                   NaN       NaN   20.750000
# 50%     249.500000                                   NaN       NaN   48.500000
# 75%     374.250000                                   NaN       NaN   73.250000
# max     499.000000                                   NaN       NaN   99.000000

# %%
sess["Device"].unique()
# Out:
# array(['Microsoft', 'Apple', 'HTC', 'Motorola', 'Huawei', 'Samsung',
#        'Google', 'sbnnz', 'thbhn', 'ouafw', 'dcppv', 'xtzqw', 'qxugb'],
#       dtype=object)

# %%
reat.describe(include="all")
# Out:
#          Unnamed: 0                            Content ID  \
# count   25553.00000                                 25553
# unique          NaN                                   980
# top             NaN  81abd65a-3b76-4574-a0a7-db6bf7184ae2
# freq            NaN                                    49
# mean    12776.00000                                   NaN
# std      7376.66005                                   NaN
# min         0.00000                                   NaN
# 25%      6388.00000                                   NaN
# 50%     12776.00000                                   NaN
# 75%     19164.00000                                   NaN
# max     25552.00000                                   NaN
#
#                                      User ID   Type             Datetime
# count                                  22534  24573                25553
# unique                                   500     16                25542
# ...

# %%
reat["User ID"].value_counts()
# Out:
# 68724f58-bc4d-4ab0-a4e1-60cdd5e95e7d    65
# c76c3393-88e2-47b0-ac37-dc4f2053f5a5    65
# 0871bb31-3d6e-4e4c-ab19-95a262cac0d4    63
# 4fe1900d-5e78-41a3-88ed-18e6889c6c77    62
# 3956593b-7739-426a-b7a5-e841c95a5df9    62
#                                         ..
# 9664d628-9163-4aae-94e0-311f3bdb2f11    31
# b4a6b3ac-b6af-4525-8d59-7afc00ff279d    30
# e57c1d53-11ce-4df6-bb4b-85647776fd6d    30
# 90898216-e580-46c0-8e79-f2df84a9676d    30
# a710ab29-b72a-42c8-a79b-42e63d4a8bfd    29
# Name: User ID, Length: 500, dtype: int64

# %%
reat["User ID"].unique()
# Out:
# array([nan, '5d454588-283d-459d-915d-c48a2cb4c27f',
#        '92b87fa5-f271-43e0-af66-84fac21052e6',
#        '163daa38-8b77-48c9-9af6-37a6c1447ac2',
#        '34e8add9-0206-47fd-a501-037b994650a2',
#        '9b6d35f9-5e15-4cd0-a8d7-b1f3340e02c4',
#        '7918d465-0953-4f20-9e28-539e74c82e2f',
#        'fa3e42f0-71d8-455f-b024-e52d5c27a145',
#        'b0c22f82-b882-4394-bf27-6dfadf26e5c2',
#        '1932a904-86ba-4438-bb52-b7e6516a4019',
#        'f50ac030-3af8-4e07-aacf-dccff353b8f6',
#        'b09e3125-2162-443b-bea0-25895b7605bc',
#        'b143cd2b-20b1-4e9c-9bb7-cfb359b33d01',
#        '48e834aa-fd4a-4206-93e8-ac8fdac613bc',
#        '7246fed1-8725-4dbb-bccd-5451346f122d',
#        '9664d628-9163-4aae-94e0-311f3bdb2f11',
#        '2dd186bb-7a28-4e80-99c7-f1936afc7b49',
#        'f4ed8f9c-5eac-4d77-a206-c60afda2921a',
#        '35d6a1f3-e358-4d4b-8074-05f3b7f35c2a',
#        'c64c5004-6ab5-4faa-9fcd-8039fe57799d',
#        '4cff698b-def1-497c-a78e-75058de67fe8',
# ...

# %%
cont["Category"].value_counts()
# Out:
# technology           71
# animals              67
# travel               67
# culture              63
# science              63
# fitness              61
# food                 61
# healthy eating       61
# cooking              60
# soccer               58
# tennis               58
# education            57
# dogs                 56
# studying             55
# veganism             48
# public speaking      48
# Fitness               5
# Science               4
# Animals               4
# Soccer                3
# "soccer"              3
# "culture"             3
# Education             2
# "dogs"                2
# Food                  2
# Studying              2
# Travel                2
# Veganism              1
# "animals"             1
# "studying"            1
# Culture               1
# Public Speaking       1
# Healthy Eating        1
# "veganism"            1
# "tennis"              1
# "public speaking"     1
# "technology"          1
# Technology            1
# ...

# %%
cont["Category"].unique()
# Out:
# array(['Studying', 'healthy eating', 'technology', 'food', 'cooking',
#        'dogs', 'soccer', 'public speaking', 'science', 'tennis', 'travel',
#        'fitness', 'education', 'studying', 'veganism', 'Animals',
#        'animals', 'culture', '"culture"', 'Fitness', '"studying"',
#        'Veganism', '"animals"', 'Travel', '"soccer"', 'Education',
#        '"dogs"', 'Technology', 'Soccer', '"tennis"', 'Culture', '"food"',
#        'Food', '"technology"', 'Healthy Eating', '"cooking"', 'Science',
#        '"public speaking"', '"veganism"', 'Public Speaking', '"science"'],
#       dtype=object)

# %%
cont.describe(include="all")
# Out:
#          Unnamed: 0                            Content ID  \
# count   1000.000000                                  1000
# unique          NaN                                  1000
# top             NaN  e6193423-0d30-4439-884a-ea22fea68522
# freq            NaN                                     1
# mean     499.500000                                   NaN
# std      288.819436                                   NaN
# min        0.000000                                   NaN
# 25%      249.750000                                   NaN
# 50%      499.500000                                   NaN
# 75%      749.250000                                   NaN
# max      999.000000                                   NaN
#
#                                      User ID   Type    Category  \
# count                                   1000   1000        1000
# unique                                   446      4          41
# top     72d2587e-8fae-4626-a73d-352e6465ba0f  photo  technology
# ...

# %%
reat_cont = pd.merge(reat,cont, how= "outer")
reat_cont.head()
# Out:
#    Unnamed: 0                            Content ID  \
# 0           0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1           1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2           2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3           3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4           4  97522e57-d9ab-4bd6-97bf-c24d952602d2
#
#                                 User ID     Type             Datetime  \
# 0                                   NaN      NaN  2021-04-22 15:17:15
# 1  5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2  92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# 3  163daa38-8b77-48c9-9af6-37a6c1447ac2   scared  2021-04-18 05:13:58
# 4  34e8add9-0206-47fd-a501-037b994650a2  disgust  2021-01-06 19:13:01
#
#   Category  URL
# 0      NaN  NaN
# 1      NaN  NaN
# 2      NaN  NaN
# 3      NaN  NaN
# 4      NaN  NaN

# %%
reat_cont.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26553 entries, 0 to 26552
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26553 non-null  int64
#  1   Content ID  26553 non-null  object
#  2   User ID     23534 non-null  object
#  3   Type        25573 non-null  object
#  4   Datetime    25553 non-null  object
#  5   Category    1000 non-null   object
#  6   URL         801 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 1.6+ MB

# %%
reat_cont.describe(include="all")
# Out:
#           Unnamed: 0                            Content ID  \
# count   26553.000000                                 26553
# unique           NaN                                  1000
# top              NaN  4dd4da35-453e-466d-95ca-b1a7710fac1f
# freq             NaN                                    50
# mean    12313.660528                                   NaN
# std      7604.684830                                   NaN
# min         0.000000                                   NaN
# 25%      5638.000000                                   NaN
# 50%     12276.000000                                   NaN
# 75%     18914.000000                                   NaN
# max     25552.000000                                   NaN
#
#                                      User ID   Type             Datetime  \
# count                                  23534  25573                25553
# unique                                   500     20                25542
# ...

# %%
reat_cont.head(100)
# Out:
#     Unnamed: 0                            Content ID  \
# 0            0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1            1  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 2            2  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 3            3  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 4            4  97522e57-d9ab-4bd6-97bf-c24d952602d2
# ..         ...                                   ...
# 95          95  356fff80-da4d-4785-9f43-bc1261031dc6
# 96          96  356fff80-da4d-4785-9f43-bc1261031dc6
# 97          97  356fff80-da4d-4785-9f43-bc1261031dc6
# 98          98  356fff80-da4d-4785-9f43-bc1261031dc6
# 99          99  356fff80-da4d-4785-9f43-bc1261031dc6
#
#                                  User ID     Type             Datetime  \
# 0                                    NaN      NaN  2021-04-22 15:17:15
# 1   5d454588-283d-459d-915d-c48a2cb4c27f  disgust  2020-11-07 09:43:50
# 2   92b87fa5-f271-43e0-af66-84fac21052e6  dislike  2021-06-17 12:22:51
# ...

# %%
reat_cont_dup = reat_cont.duplicated()

# %%
reat_cont_dup.value_counts()
# Out:
# False    26553
# dtype: int64

# %%
reat_cont.isnull().sum()
# Out:
# Unnamed: 0        0
# Content ID        0
# User ID        3019
# Type            980
# Datetime       1000
# Category      25553
# URL           25752
# dtype: int64

# %%
reat_cont_drop = reat_cont.drop(["URL","Category"],axis = 1 )

# %%
reat_cont_drop.isnull().sum()
# Out:
# Unnamed: 0       0
# Content ID       0
# User ID       3019
# Type           980
# Datetime      1000
# dtype: int64

# %%
reat_cont_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26553 entries, 0 to 26552
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26553 non-null  int64
#  1   Content ID  26553 non-null  object
#  2   User ID     23534 non-null  object
#  3   Type        25573 non-null  object
#  4   Datetime    25553 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.2+ MB

# %%
reat_cont_drop_row = reat_cont_drop.dropna(axis=0)

# %%
reat_cont_drop_row.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22534 entries, 1 to 25552
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  22534 non-null  int64
#  1   Content ID  22534 non-null  object
#  2   User ID     22534 non-null  object
#  3   Type        22534 non-null  object
#  4   Datetime    22534 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 1.0+ MB

# %%
reat_cont_drop_row.isnull().sum()
# Out:
# Unnamed: 0    0
# Content ID    0
# User ID       0
# Type          0
# Datetime      0
# dtype: int64

# %%
reat_cont_drop_row.describe(include="all")
# Out:
#           Unnamed: 0                            Content ID  \
# count   22534.000000                                 22534
# unique           NaN                                   962
# top              NaN  ff883828-a610-492d-8635-8a777eaad25f
# freq             NaN                                    44
# mean    12780.053297                                   NaN
# std      7377.719645                                   NaN
# min         1.000000                                   NaN
# 25%      6390.250000                                   NaN
# 50%     12788.500000                                   NaN
# 75%     19171.750000                                   NaN
# max     25552.000000                                   NaN
#
#                                      User ID   Type             Datetime
# count                                  22534  22534                22534
# unique                                   500     16                22524
# ...

# %%
prof_sess = pd.merge(prof,sess, how= "inner")

# %%
prof_sess.head()
# Out:
#    Unnamed: 0                               User ID  \
# 0           0  4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 1           1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 2           2  a8229d24-f219-4930-a382-24049a8f73bb
# 3           3  8f41c07f-db4f-44f3-ae81-1f99cee047eb
# 4           4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
#
#                                      Interests  Age     Device  Duration
# 0                                       [0, 1]   41  Microsoft        11
# 1                                   ['tennis']   23      Apple        51
# 2  ['fitness', 'cooking', 'animals', 'travel']   25        HTC        25
# 3        ['technology', 'culture', 'veganism']    2   Motorola        68
# 4                                ['education']   44     Huawei        57

# %%
prof_sess.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   User ID     500 non-null    object
#  2   Interests   500 non-null    object
#  3   Age         500 non-null    int64
#  4   Device      500 non-null    object
#  5   Duration    500 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 27.3+ KB

# %%
prof_sess.isnull().sum()
# Out:
# Unnamed: 0    0
# User ID       0
# Interests     0
# Age           0
# Device        0
# Duration      0
# dtype: int64

# %%
prof_sess.describe(include="all")
# Out:
#         Unnamed: 0                               User ID    Interests  \
# count   500.000000                                   500          500
# unique         NaN                                   500          366
# top            NaN  3ae50cc3-39cc-440a-8e31-3215011f2762  ['science']
# freq           NaN                                     1           11
# mean    249.500000                                   NaN          NaN
# std     144.481833                                   NaN          NaN
# min       0.000000                                   NaN          NaN
# 25%     124.750000                                   NaN          NaN
# 50%     249.500000                                   NaN          NaN
# 75%     374.250000                                   NaN          NaN
# max     499.000000                                   NaN          NaN
#
#                Age    Device    Duration
# count   500.000000       500  500.000000
# unique         NaN        13         NaN
# ...

# %%
loca_user = pd.merge(loca,user, how= "inner")

# %%
loca_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   User ID     500 non-null    object
#  2   Address     500 non-null    object
#  3   Name        500 non-null    object
#  4   Email       500 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 23.4+ KB

# %%
loca_user.isnull().sum()
# Out:
# Unnamed: 0    0
# User ID       0
# Address       0
# Name          0
# Email         0
# dtype: int64

# %%
loca_user_prof_sess = pd.merge(loca_user,prof_sess, how= "inner")

# %%
loca_user_prof_sess.head()
# Out:
#    Unnamed: 0                               User ID  \
# 0           0  4c731e48-0377-4d7d-b4c8-b2174b774ed8
# 1           1  95258c36-5b6b-4591-85ee-0c43f503c1d5
# 2           2  a8229d24-f219-4930-a382-24049a8f73bb
# 3           3  8f41c07f-db4f-44f3-ae81-1f99cee047eb
# 4           4  3af8d78b-55c4-4ac0-8161-7cc3f6ec11c9
#
#                                              Address             Name  \
# 0        6208 Wright Mountains\nBryantfurt, AR 02531        Gary Hill
# 1  534 Williams Turnpike Suite 788\nPort Julie, W...  Michael Deering
# 2  867 Lisa Causeway Apt. 015\nWest Brentmouth, A...     Richard Bain
# 3  5687 Wilson Harbors Suite 763\nLake Robert, FL...  Kristi Mccarthy
# 4                   Unit 2614 Box 8996\nDPO AE 23660      Betty Ellis
#
#           Email                                    Interests  Age     Device  \
# 0  GHbnuothhymw                                       [0, 1]   41  Microsoft
# ...

# %%
loca_user_prof_sess.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  500 non-null    int64
#  1   User ID     500 non-null    object
#  2   Address     500 non-null    object
#  3   Name        500 non-null    object
#  4   Email       500 non-null    object
#  5   Interests   500 non-null    object
#  6   Age         500 non-null    int64
#  7   Device      500 non-null    object
#  8   Duration    500 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 39.1+ KB

# %%
loca_user_prof_sess.isnull().sum()
# Out:
# Unnamed: 0    0
# User ID       0
# Address       0
# Name          0
# Email         0
# Interests     0
# Age           0
# Device        0
# Duration      0
# dtype: int64

# %%
loca_user_prof_sess.duplicated().value_counts()
# Out:
# False    500
# dtype: int64

# %%
loca_user_prof_sess.describe(include="all")
# Out:
#         Unnamed: 0                               User ID  \
# count   500.000000                                   500
# unique         NaN                                   500
# top            NaN  3ae50cc3-39cc-440a-8e31-3215011f2762
# freq           NaN                                     1
# mean    249.500000                                   NaN
# std     144.481833                                   NaN
# min       0.000000                                   NaN
# 25%     124.750000                                   NaN
# 50%     249.500000                                   NaN
# 75%     374.250000                                   NaN
# max     499.000000                                   NaN
#
#                                                   Address               Name  \
# count                                                 500                500
# unique                                                500                500
# ...

# %%
loca_user_prof_sess["Age"].value_counts()
# Out:
# 16    19
# 38    17
# 36    16
# 41    16
# 42    15
# 28    15
# 39    15
# 5     15
# 32    14
# 6     13
# 19    13
# 10    13
# 30    13
# 14    13
# 2     13
# 15    13
# 4     12
# 26    12
# 25    12
# 9     11
# 43    11
# 23    11
# 7     10
# 11    10
# 13    10
# 0     10
# 24    10
# 27    10
# 31    10
# 3     10
# 17     9
# 21     9
# 1      9
# 33     9
# 8      9
# 35     9
# 37     9
# 20     8
# 29     8
# 34     8
# 40     8
# 18     7
# 44     6
# 12     5
# 22     5
# Name: Age, dtype: int64

# %%
loca_user_prof_sess["Age"].unique()
# Out:
# array([41, 23, 25,  2, 44, 28,  4, 30,  8, 32, 34, 42, 19, 21, 14, 29, 39,
#        38,  7,  3,  9, 16, 40,  5, 35, 36, 26, 33, 20, 11, 18,  0, 24, 10,
#        15, 17,  6, 43,  1, 22, 27, 31, 37, 13, 12], dtype=int64)

# %%
loca_user_prof_sess["Age"].mean()
# Out:
# 22.29

# %%
for x in loca_user_prof_sess.index:
    if loca_user_prof_sess.loc [x,"Age"] <10:
        loca_user_prof_sess.loc [x,"Age"]=10

# %%
loca_user_prof_sess["Age"].unique()
# Out:
# array([41, 23, 25, 10, 44, 28, 30, 32, 34, 42, 19, 21, 14, 29, 39, 38, 16,
#        40, 35, 36, 26, 33, 20, 11, 18, 24, 15, 17, 43, 22, 27, 31, 37, 13,
#        12], dtype=int64)

# %%
data_first= reat_cont_drop_row

# %%
data_second=loca_user_prof_sess

# %%
data_third = pd.merge(cont,data_second, how= "outer")

# %%
data_third.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1499 entries, 0 to 1498
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1499 non-null   int64
#  1   Content ID  1000 non-null   object
#  2   User ID     1499 non-null   object
#  3   Type        1000 non-null   object
#  4   Category    1000 non-null   object
#  5   URL         801 non-null    object
#  6   Address     500 non-null    object
#  7   Name        500 non-null    object
#  8   Email       500 non-null    object
#  9   Interests   500 non-null    object
#  10  Age         500 non-null    float64
#  11  Device      500 non-null    object
#  12  Duration    500 non-null    float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 164.0+ KB

# %%
data_third.isnull().sum()
# Out:
# Unnamed: 0      0
# Content ID    499
# User ID         0
# Type          499
# Category      499
# URL           698
# Address       999
# Name          999
# Email         999
# Interests     999
# Age           999
# Device        999
# Duration      999
# dtype: int64

# %%
data_four= pd.merge(data_second,reat, how="inner")

# %%
data_four.isnull().sum()
# Out:
# Unnamed: 0    0
# User ID       0
# Address       0
# Name          0
# Email         0
# Interests     0
# Age           0
# Device        0
# Duration      0
# Content ID    0
# Type          0
# Datetime      0
# dtype: int64

# %%
data_four= pd.merge(data_second,reat, how="outer")

# %%
data_four.isnull().sum()
# Out:
# Unnamed: 0        0
# User ID        3019
# Address       25553
# Name          25553
# Email         25553
# Interests     25553
# Age           25553
# Device        25553
# Duration      25553
# Content ID      500
# Type           1480
# Datetime        500
# dtype: int64

# %%
data_four.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26053 entries, 0 to 26052
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  26053 non-null  int64
#  1   User ID     23034 non-null  object
#  2   Address     500 non-null    object
#  3   Name        500 non-null    object
#  4   Email       500 non-null    object
#  5   Interests   500 non-null    object
#  6   Age         500 non-null    float64
#  7   Device      500 non-null    object
#  8   Duration    500 non-null    float64
#  9   Content ID  25553 non-null  object
#  10  Type        24573 non-null  object
#  11  Datetime    25553 non-null  object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 2.6+ MB

# %%
loca_user_prof_sess["Age"].unique()
# Out:
# array([41, 23, 25, 10, 44, 28, 30, 32, 34, 42, 19, 21, 14, 29, 39, 38, 16,
#        40, 35, 36, 26, 33, 20, 11, 18, 24, 15, 17, 43, 22, 27, 31, 37, 13,
#        12], dtype=int64)
